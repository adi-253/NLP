# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('economics_refined.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Date                                          Headlines  \
# 0           0  2023-01-01  ['Gazing into the crystal ball: A look into wh...
# 1           1  2023-01-02  ["Supreme Court verdict on pleas challenging t...
# 2           2  2023-01-03  ['Shipping Corporation selloff to set sail wit...
# 3           3  2023-01-04  ['India Inc, put R&D where your mouth is', 'Ta...
# 4           4  2023-01-05  ['Jharkhand govt plans to seek denotification ...
#
#                                       Financial_News
# 0  ['Gazing into the crystal ball: A look into wh...
# 1  ["Supreme Court verdict on pleas challenging t...
# 2  ['Rice prices up 15%, Palm oil seen rising too...
# 3  ['Takes GoI and RBI to policy tango', 'Warehou...
# 4  ['Give national status and funds for Gangasaga...

# %%
import ast
df["Financial_News"]=df["Financial_News"].apply(ast.literal_eval)

# %%
df["Headlines"]=df["Headlines"].apply(ast.literal_eval)

# %%
len(df.iloc[0,-2])
# Out:
# 166

# %%
df.iloc[1,-1][15]
# Out:
# 'View: 2023 could be anything, from boom year to crash'

# %%
df1=pd.read_csv("SEntFiN.csv")

# %%
df1.head()
# Out:
#    S No.                                              Title  \
# 0      1  SpiceJet to issue 6.4 crore warrants to promoters
# 1      2                  MMTC Q2 net loss at Rs 10.4 crore
# 2      3  Mid-cap funds can deliver more, stay put: Experts
# 3      4             Mid caps now turn into market darlings
# 4      5  Market seeing patience, if not conviction: Pra...
#
#                        Decisions  Words
# 0        {'SpiceJet': 'neutral'}      8
# 1            {'MMTC': 'neutral'}      8
# 2  {'Mid-cap funds': 'positive'}      8
# 3       {'Mid caps': 'positive'}      7
# 4          {'Market': 'neutral'}      8

# %%
len(df1)
# Out:
# 10753

# %%
import s3fs
import pandas as pd

uri = "s3://desiquant/data/news/ASIANPAINT.parquet.gz"

s3_params = {
"endpoint_url": "https://cbabd13f6c54798a9ec05df5b8070a6e.r2.cloudflarestorage.com",
"key": "5c8ea9c516abfc78987bc98c70d2868a", # FREE credentials for public access!
"secret": "0cf64f9f0b64f6008cf5efe1529c6772daa7d7d0822f5db42a7c6a1e41b3cadf", # FREE credentials for public access!
"client_kwargs": {
    "region_name": "auto"
    },
}

df = pd.read_parquet(uri, storage_options=s3_params)
df.tail() # view sample data
# Out:
#                                                title     feed_type  \
# 0  Mid-day Market | Nifty slips below 19,300 on h...  news-article
# 1  Taking Stock: Market squanders opening gains t...  news-article
# 2  Paytm, Zomato, PolicyBazaar can be the next Re...  news-article
# 3                  Broker’s call: Asian Paints (Buy)  news-article
# 4  Sensex rises over 100 points, Nifty above 19,5...  news-article
# 5  Fitch Fury: Rs 3.56 lakh crore of wealth wiped...  news-article
# 6  Sensex falls 300 points as weak economic data ...  news-article
# 7  Asian Paints, Bajaj Finance among 10 stocks wi...  news-article
# 8  Reduce Asian Paints; target of Rs 3000: ICICI ...  news-article
# 9    Hold Asian Paints; target of Rs 3675: Sharekhan  news-article
#
#                                                 link  \
# 0  https://www.moneycontrol.com/news/business/mar...
# 1  https://www.moneycontrol.com/news/business/mar...
# 2  https://economictimes.indiatimes.com/markets/e...
# 3  https://www.thehindubusinessline.com/markets/b...
# 4  https://economictimes.indiatimes.com/markets/s...
# 5  https://www.moneycontrol.com/news/business/mar...
# 6  https://economictimes.indiatimes.com/markets/s...
# 7  https://economictimes.indiatimes.com/markets/s...
# 8  https://www.moneycontrol.com/news/business/sto...
# 9  https://www.moneycontrol.com/news/business/sto...
#
#                                          description                     date  \
# 0  Despite the selling pressure, Bajaj Auto and B...  2023-08-25 14:01:27.000
# 1  Top Nifty losers included Reliance Industries,...  2023-08-24 15:46:07.000
# 2  “Paytm, Zomato, PolicyBazaar, Nykaa are entrep...  2023-08-09 11:19:00.000
# 3  Asian Paints posts 10% YoY vol growth in Q1-FY...  2023-08-08 19:23:35.000
# 4  From the Sensex pack, M&M, NTPC, Bajaj Finserv...  2023-08-07 09:42:00.000
# 5  Biggest losers on the Nifty were Hero MotoCorp...  2023-08-02 15:43:37.000
# 6  Among the Sensex stocks, Tata Steel, L&T, JSW ...  2023-08-02 09:47:00.000
# 7  ETMarkets has carefully selected 10 stocks fro...  2023-08-01 18:16:00.000
# 8  ICICI Securities recommended reduce rating on ...  2023-07-29 21:29:05.000
# 9  Sharekhan recommended Hold rating on Asian Pai...  2023-07-28 16:32:48.000
#
#                                                image  \
# 0  https://pocket-image-cache.com/direct?url=http...
# 1  https://pocket-image-cache.com/direct?url=http...
# 2  https://pocket-image-cache.com/direct?url=http...
# 3  https://pocket-image-cache.com/direct?url=http...
# 4  https://pocket-image-cache.com/direct?url=http...
# 5  https://pocket-image-cache.com/direct?url=http...
# 6  https://pocket-image-cache.com/direct?url=http...
# 7  https://pocket-image-cache.com/direct?url=http...
# 8  https://pocket-image-cache.com/direct?url=http...
# 9  https://pocket-image-cache.com/direct?url=http...
#
#                                            publisher  \
# 0  {'logo': 'https://assets.tickertape.in/images/...
# 1  {'logo': 'https://assets.tickertape.in/images/...
# 2  {'logo': 'https://assets.tickertape.in/images/...
# 3  {'logo': 'https://assets.tickertape.in/images/...
# 4  {'logo': 'https://assets.tickertape.in/images/...
# 5  {'logo': 'https://assets.tickertape.in/images/...
# 6  {'logo': 'https://assets.tickertape.in/images/...
# 7  {'logo': 'https://assets.tickertape.in/images/...
# 8  {'logo': 'https://assets.tickertape.in/images/...
# 9  {'logo': 'https://assets.tickertape.in/images/...
#
#                                               stocks                       _id
# 0  [{'sid': 'ASPN'}, {'sid': 'BJFS'}, {'sid': 'BA...  64e86b4aef976d312471dd64
# 1  [{'sid': 'ASPN'}, {'sid': 'BRIT'}, {'sid': 'BP...  64e73384ef976d312471d5c2
# 2  [{'sid': 'ASPN'}, {'sid': 'RELI'}, {'sid': 'TI...  64d32f81a5cfe86dc38a31d2
# 3                                  [{'sid': 'ASPN'}]  64d24d6ca5cfe86dc38a2d3f
# 4  [{'sid': 'ASPN'}, {'sid': 'BJFS'}, {'sid': 'ID...  64d0702ca5cfe86dc38a1f10
# 5  [{'sid': 'ASPN'}, {'sid': 'DIVI'}, {'sid': 'EI...  64ca310f7a206429c6a9b939
# 6  [{'sid': 'ASPN'}, {'sid': 'BJFS'}, {'sid': 'ID...  64c9dfaf7a206429c6a9b60c
# 7  [{'sid': 'ASPN'}, {'sid': 'BJFN'}, {'sid': 'ID...  64c905b67a206429c6a9b16b
# 8                 [{'sid': 'ASPN'}, {'sid': 'ICCI'}]  64c53d32042faa63cb2a3188
# 9                                  [{'sid': 'ASPN'}]  64c3a561042faa63cb2a298b

# %%
df.tail()
# Out:
#                                                   title     feed_type  \
# 1873  Asian Paints Q4: a few bright spots on a dull ...  news-article
# 1874     Asian Paints Q4 profit rises 4% to Rs481 crore  news-article
# 1875  Asian Paints acquires remaining 49% stake in S...  news-article
# 1876  Sensex, Nifty end in red; HUL, Tata Motors, L&...  news-article
# 1877  The story behind RK Laxman’s ‘Gattu ke papa’ a...  news-article
#
#                                                    link  \
# 1873  https://www.livemint.com/Opinion/3RnBgLvGf88vO...
# 1874  https://www.livemint.com/Companies/VAdoKHbpLPW...
# 1875  http://www.livemint.com/Companies/6nd4DMXzfdTz...
# 1876  https://www.moneycontrol.com/news/business/mar...
# 1877  https://economictimes.indiatimes.com/blogs/et-...
#
#                                             description  \
# 1873  The silver lining is that Asian Paints has tak...
# 1874  Asian Paints net profit rose to Rs481 crore in...
# 1875  Asian Paints acquires the remaining 49% stake ...
# 1876  Asian Paints, SBI, Tata Motors, HUL and Maruti...
# 1877  By Anvar Alikhan There are legends about what ...
#
#                          date  \
# 1873  2018-05-11 10:02:45.285
# 1874  2018-05-10 18:02:07.523
# 1875  2017-12-12 18:03:31.818
# 1876  2016-10-05 14:00:44.000
# 1877  2015-02-02 09:32:42.000
#
#                                                   image  \
# 1873  https://pocket-image-cache.com/direct?url=http...
# 1874  https://pocket-image-cache.com/direct?url=http...
# 1875  https://pocket-image-cache.com/direct?url=http...
# 1876  https://pocket-image-cache.com/direct?url=http...
# 1877  https://pocket-image-cache.com/direct?url=http...
#
#                                               publisher  \
# 1873  {'logo': 'https://www.smallcase.com/images/new...
# 1874  {'logo': 'https://www.smallcase.com/images/new...
# 1875  {'logo': 'https://www.smallcase.com/images/new...
# 1876  {'logo': 'https://assets.tickertape.in/images/...
# 1877  {'logo': 'https://assets.tickertape.in/images/...
#
#                                                  stocks  \
# 1873          [{'sid': 'ASPN', 'initialPrice': 1217.7}]
# 1874         [{'sid': 'ASPN', 'initialPrice': 1222.55}]
# 1875         [{'sid': 'ASPN', 'initialPrice': 1125.85}]
# 1876  [{'sid': 'AXBK'}, {'sid': 'ASPN'}, {'sid': 'BA...
# 1877                                  [{'sid': 'ASPN'}]
#
#                            _id
# 1873  5af51ced4a49a6290af3997a
# 1874  5af43bc7d77a551638f4faf1
# 1875  5a2fcc9bcb6aa379ea8b82c4
# 1876  5f08359ad0ccf9eb28dfd73e
# 1877  5f083c0ad0ccf9eb28dfd7a2
